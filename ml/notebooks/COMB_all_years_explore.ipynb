# %% [markdown]
# # Data Exploration for COMB_all_years.csv
# This notebook automatically loads and explores the dataset.

# %%
import pandas as pd
df = pd.read_csv('d:/Projects/2026.06.11 market-anomaly-detector/market-anomaly-detector/ml/data/raw/COMB_all_years.csv', on_bad_lines='skip')
df.head()
# Out:
#   COMPANY ID   MAIN TYPE    SUB TYPE      SHORT NAME  TRADING DATE  \
# 0       COMB             N       0.0  COMMERCIAL BANK    04-JAN-21
# 1       COMB             N       0.0  COMMERCIAL BANK    05-JAN-21
# 2       COMB             N       0.0  COMMERCIAL BANK    06-JAN-21
# 3       COMB             N       0.0  COMMERCIAL BANK    07-JAN-21
# 4       COMB             N       0.0  COMMERCIAL BANK    08-JAN-21
#
#     PRICE HIGH (Rs.)   PRICE LOW (Rs.)  CLOSE PRICE (Rs.)  OPEN PRICE (Rs.)  \
# 0               83.6              81.0               83.3              83.3
# 1               83.9              83.0               83.2              83.2
# 2               83.2              82.0               83.0              83.0
# 3               83.0              81.9               82.7              82.7
# 4               82.8              81.9               82.4              82.4
#
#   TRADE VOLUME (No.)  SHARE VOLUME (No.)   TURNOVER (Rs.)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   COMPANY ID           606 non-null    object
#  1     MAIN TYPE          606 non-null    object
#  2   SUB TYPE             606 non-null    float64
#  3    SHORT NAME          606 non-null    object
#  4   TRADING DATE         606 non-null    object
#  5    PRICE HIGH (Rs.)    606 non-null    float64
#  6    PRICE LOW (Rs.)     602 non-null    float64
#  7   CLOSE PRICE (Rs.)    606 non-null    float64
#  8   OPEN PRICE (Rs.)     604 non-null    float64
#  9   TRADE VOLUME (No.)   606 non-null    object
#  10  SHARE VOLUME (No.)   606 non-null    object
#  11  TURNOVER (Rs.)       606 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 56.9+ KB

# %%
df.isnull().sum()
# Out:
# COMPANY ID             0
#   MAIN TYPE            0
# SUB TYPE               0
#  SHORT NAME            0
# TRADING DATE           0
#  PRICE HIGH (Rs.)      0
#  PRICE LOW (Rs.)       4
# CLOSE PRICE (Rs.)      0
# OPEN PRICE (Rs.)       2
# TRADE VOLUME (No.)     0
# SHARE VOLUME (No.)     0
# TURNOVER (Rs.)         0
# dtype: int64
