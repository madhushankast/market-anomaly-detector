# %% [markdown]
# # Data Exploration for JKH_all_years.csv
# This notebook automatically loads and explores the dataset.

# %%
import pandas as pd
df = pd.read_csv('d:/Projects/2026.06.11 market-anomaly-detector/market-anomaly-detector/ml/data/raw/JKH_all_years.csv', on_bad_lines='skip')
df.head()
# Out:
#   COMPANY ID   MAIN TYPE    SUB TYPE  SHORT NAME  TRADING DATE  \
# 0        JKH             N       0.0          JKH    04-JAN-21
# 1        JKH             N       0.0          JKH    05-JAN-21
# 2        JKH             N       0.0          JKH    06-JAN-21
# 3        JKH             N       0.0          JKH    07-JAN-21
# 4        JKH             N       0.0          JKH    08-JAN-21
#
#     PRICE HIGH (Rs.)  PRICE LOW (Rs.)  CLOSE PRICE (Rs.)  OPEN PRICE (Rs.)  \
# 0              151.0           149.50              149.6             149.6
# 1              151.0           149.80              150.0             150.0
# 2              150.1           149.80              149.8             149.8
# 3              149.8           148.10              148.5             148.5
# 4              150.0           148.25              149.0             149.0
#
#   TRADE VOLUME (No.)  SHARE VOLUME (No.)   TURNOVER (Rs.)
# 0                 181        1,208,543.00  181,179,679.10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   COMPANY ID           595 non-null    object
#  1     MAIN TYPE          595 non-null    object
#  2   SUB TYPE             595 non-null    float64
#  3    SHORT NAME          595 non-null    object
#  4   TRADING DATE         595 non-null    object
#  5    PRICE HIGH (Rs.)    595 non-null    float64
#  6    PRICE LOW (Rs.)     586 non-null    object
#  7   CLOSE PRICE (Rs.)    595 non-null    float64
#  8   OPEN PRICE (Rs.)     588 non-null    float64
#  9   TRADE VOLUME (No.)   595 non-null    object
#  10  SHARE VOLUME (No.)   595 non-null    object
#  11  TURNOVER (Rs.)       595 non-null    object
# dtypes: float64(4), object(8)
# memory usage: 55.9+ KB

# %%
df.isnull().sum()
# Out:
# COMPANY ID             0
#   MAIN TYPE            0
# SUB TYPE               0
#  SHORT NAME            0
# TRADING DATE           0
#  PRICE HIGH (Rs.)      0
#  PRICE LOW (Rs.)       9
# CLOSE PRICE (Rs.)      0
# OPEN PRICE (Rs.)       7
# TRADE VOLUME (No.)     0
# SHARE VOLUME (No.)     0
# TURNOVER (Rs.)         0
# dtype: int64
