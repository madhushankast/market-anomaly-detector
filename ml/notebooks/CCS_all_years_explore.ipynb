# %% [markdown]
# # Data Exploration for CCS_all_years.csv
# This notebook automatically loads and explores the dataset.

# %%
import pandas as pd
df = pd.read_csv('d:/Projects/2026.06.11 market-anomaly-detector/market-anomaly-detector/ml/data/raw/CCS_all_years.csv', on_bad_lines='skip')
df.head()

# %%
df.info()

# %%
df.isnull().sum()
